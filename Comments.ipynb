# %%
# !pip install tqdm
# !pip install openai==0.28
# !pip install --upgrade gensim nltk pyLDAvis
# !pip install spacy
# !pip install wordcloud
# !python -m spacy download en_core_web_sm

# %%
# Importing necessary libraries

import csv
import datetime as date
import json
import os
import time
import statistics

import numpy as np
import pandas as pd
import requests
from collections import Counter

from urllib.parse import quote
from requests.exceptions import SSLError

import pandas as pd
import gensim
from gensim.utils import simple_preprocess
from gensim.models.phrases import Phrases, Phraser
import nltk
from nltk.corpus import stopwords
from gensim.corpora import Dictionary
from gensim.models import LdaMulticore
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import openai
import os
import time
import pandas as pd
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

# %%
pip install lingua-language-detector
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Collecting lingua-language-detector
#   Downloading lingua_language_detector-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (349 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.2/349.2 kB 6.6 MB/s eta 0:00:00
# Downloading lingua_language_detector-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (74.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 MB 12.3 MB/s eta 0:00:00
# Installing collected packages: lingua-language-detector
# Successfully installed lingua-language-detector-2.0.2

# %%
import requests
import csv
import os
from urllib.parse import quote
from datetime import datetime, timedelta

# Function to fetch reviews
def get_reviews(appid, cursor="*"):
    cursor = quote(cursor)
    url = f"https://store.steampowered.com/appreviews/{appid}?json=1&filter={filter}&language={language}&day_range={day_range}&cursor={cursor}&review_type={review_type}&purchase_type={purchase_type}&num_per_page={num_per_page}"
    #print(f"Fetching URL for AppID {appid}: {url}")
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching reviews for AppID {appid}: {e}")
        return None

# Function to save reviews to a single CSV file
def save_reviews_to_csv(reviews, appid):
    file_name = "comments.csv"
    with open(file_name, "a", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['appid', 'review', 'date_created'])
        for review in reviews:
            # Convert the timestamp to mm/dd/yy format
            date_created = datetime.utcfromtimestamp(review['timestamp_created']).strftime('%m/%d/%y')
            writer.writerow({'appid': appid, 'review': review['review'], 'date_created': date_created})
    print(f"Saved reviews for AppID {appid} to comments.csv")

# Function to save games with no reviews
def save_no_reviews_list():
    with open("games_with_no_comments.csv", "w", newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['appid', 'name'])
        writer.writeheader()
        writer.writerows(games_with_no_comments)
    print(f"Saved updated games with no comments to games_with_no_comments.csv")

# Process reviews for a single game
def process_game_reviews(appid):
    total_reviews = 0
    cursor = "*"
    game_reviews = []

    while total_reviews < max_reviews:
        data = get_reviews(appid, cursor)
        if data is None or 'reviews' not in data or not data['reviews']:
            print(f"No more reviews for AppID {appid}.")
            if total_reviews == 0:  # No reviews at all
                games_with_no_comments.append({'appid': appid, 'name': f"Game_{appid}"})  # Example name, replace with actual if available
                save_no_reviews_list()  # Save the no_reviews list after every addition
            break

        for review in data['reviews']:
            review_timestamp = datetime.utcfromtimestamp(review['timestamp_created'])

            # Check if review is older than 504 days
            if review_timestamp < cutoff_date:
                print(f"Reached the 504-day cutoff date for AppID {appid}.")
                continue  # Skip this review

            game_reviews.append(review)
            total_reviews += 1

            # If we hit 500 reviews, stop collecting
            if total_reviews >= max_reviews:
                print(f"Reached the limit of 500 reviews for AppID {appid}.")
                break

        # Update the cursor and continue if there are more reviews
        cursor = data['cursor']
        if cursor == "*":
            break

        if total_reviews < 100:  # Less than max, reached end of page
            print(f"Reached the end of page for AppID {appid}.")
            break

    if game_reviews:
        save_reviews_to_csv(game_reviews, appid)

# Function to check the last processed appid from the comments.csv file
def get_last_processed_appid():
    file_name = "comments.csv"
    if not os.path.exists(file_name):
        return None  # No file exists, so no appid has been processed yet

    with open(file_name, "r", newline='', encoding='utf-8') as f:
        reader = csv.DictReader(f)
        rows = list(reader)
        if rows:
            # Handle the .0 case by converting to a string first, then to an int safely
            appid_str = rows[-1]['appid']
            print(f"Last processed appid in comments.csv: {appid_str}")  # Debugging print
            return str(int(float(appid_str)))  # Return the last processed appid as string
    return None
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Convert appid_list from a Pandas Series to a list
appid_list = covid_ids.tolist()  # Make sure to convert it to a list
filter = 'all'
language = 'english'
day_range = 504  # Limit reviews to the past 504 days
review_type = 'all'
purchase_type = 'all'  # default is Steam
num_per_page = 100  # max reviews per page
max_reviews = 500  # Cap at 500 reviews
cutoff_date = datetime.now() - timedelta(days=504)  # 504 days ago

# Lists to store games with no comments
games_with_no_comments = []
total_games = len(appid_list)  # Total number of games to process
games_completed = 0  # Counter for number of games processed

# Debugging print to verify appid_list contents
print(f"AppID List: {appid_list[:10]}...")  # Printing first 10 appids for sanity check
print(f"Total Games: {total_games}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8e606f1c3b12> in <cell line: 2>()
#       1 # Convert appid_list from a Pandas Series to a list
# ----> 2 appid_list = covid_ids.tolist()  # Make sure to convert it to a list
#       3 filter = 'all'
#       4 language = 'english'
#       5 day_range = 504  # Limit reviews to the past 504 days
#
# NameError: name 'covid_ids' is not defined

# %%
# Start the script and resume from the last appid processed
last_processed_appid = get_last_processed_appid()

if last_processed_appid is not None:
    print(f"Resuming from appid {last_processed_appid}")
else:
    print("Starting fresh")

# Process each game in the appid list, skipping already processed ones
found_last_processed = last_processed_appid is None  # True if we start fresh

with open("comments.csv", "a", newline='', encoding='utf-8') as f:
    if last_processed_appid is None:
        writer = csv.DictWriter(f, fieldnames=['appid', 'review', 'date_created'])
        writer.writeheader()  # Write header for the CSV if starting fresh

for appid in appid_list:
    # Skip until we find the last processed appid
    if not found_last_processed:
        print(f"Comparing {appid} with {last_processed_appid}")  # Debugging print to verify comparison
        if int(appid) == int(last_processed_appid):
            found_last_processed = True  # Found it, start processing next one
        continue

    # Process this appid
    process_game_reviews(appid)
    games_completed += 1
    print(f"Completed {games_completed}/{total_games} games.\n")  # Show progress

print("Processing complete.")

# %%
# load comments.csv:
comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/comments.csv')
print(comments_df.head())

# load no comments:
no_comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/games_with_no_comments.csv')
print(no_comments_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-336052f51e79> in <cell line: 2>()
#       1 # load comments.csv:
# ----> 2 comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/comments.csv')
#       3 print(comments_df.head())
#       4
#       5 # load no comments:
#
# NameError: name 'pd' is not defined

# %%
# how many unique appid in comments:
print("Games with comments: ", comments_df['appid'].nunique())

#how many games in no_comments:
print("Games with no comments: ", no_comments_df['appid'].nunique())

# %%
comments_df.head()

# %%
import concurrent.futures
import pandas as pd
from lingua import LanguageDetectorBuilder
from tqdm import tqdm
import os

# Initialize language detector
detector = LanguageDetectorBuilder.from_all_languages().build()

# Function to detect language with error handling
def detect_language_safe(comment):
    if isinstance(comment, str):  # Only process if it's a string
        lang = detector.detect_language_of(comment)
        return lang.iso_code_639_1 if lang else 'unknown'
    return 'unknown'

# Multithreading with progress tracking
def multithreaded_language_detection(df, column_name='review', num_threads=4, chunk_size=10000, checkpoint_path='progress_checkpoint.csv'):
    total_rows = len(df)

    # Check if a checkpoint exists
    if os.path.exists(checkpoint_path):
        print("Resuming from checkpoint...")
        processed_df = pd.read_csv(checkpoint_path)
        start_idx = len(processed_df)  # Resume from where you left off
        df = df[start_idx:]  # Only process remaining rows
    else:
        processed_df = pd.DataFrame()
        start_idx = 0

    # Process the data in chunks
    for chunk_start in tqdm(range(0, total_rows, chunk_size), desc="Processing batches"):
        chunk_end = min(chunk_start + chunk_size, total_rows)
        df_chunk = df.iloc[chunk_start:chunk_end].copy()  # Copy to avoid SettingWithCopyWarning

        with concurrent.futures.ThreadPoolExecutor(max_workers=num_threads) as executor:
            results = list(executor.map(detect_language_safe, df_chunk[column_name]))

        # Assign results to the DataFrame chunk using .loc
        df_chunk.loc[:, 'lang_detected'] = results

        # Append the processed chunk to the main DataFrame
        processed_df = pd.concat([processed_df, df_chunk], ignore_index=True)

        # Save checkpoint after each chunk
        processed_df.to_csv(checkpoint_path, index=False)


multithreaded_language_detection(comments_df, column_name='review', num_threads=1, chunk_size=10000, checkpoint_path='language_detection_progress.csv')

# %%
# loading:
comments_df = pd.read_csv('/content/language_detection_progress.csv')

# %%
# saving comment data:
comments_df.to_csv('/content/drive/MyDrive/Dat490/Data/comments.csv', index=False)

# %%
comments_df.head()

# %%
#strip "IsoCode639-1.":
comments_df['lang_detected'] = comments_df['lang_detected'].str.replace('IsoCode639_1.', '')

# lang_detected values:
print(comments_df['lang_detected'].value_counts())

# %%
#print number of comments:
print("Number of comments: ", len(comments_df))

#print number of "english comments":
print("Number of English Comments: ", len(comments_df[comments_df['lang_detected'] == 'EN']))



#print number of "unknown":
print("Number of unknown: ", len(comments_df[comments_df['lang_detected'] == 'unknown']))

#print number of non EN or unknown:
print("Number of non EN or unknown: ", len(comments_df[(comments_df['lang_detected'] != 'EN') & (comments_df['lang_detected'] != 'unknown')]))

# %%
# changing lang_detected to "Language":
comments_df.rename(columns={'lang_detected': 'Language'}, inplace=True)

# %%
#top 10 languages detected bar chart:
comments_df['Language'].value_counts().head(10).plot(kind='bar')

# %%
#df of non english languages, excluding unknown:
foreign_comments_df = comments_df[(comments_df['Language'] != 'EN') & (comments_df['Language'] != 'unknown')]

# bar chart of top 10 languages, titled: Top Non-English Comments:
# y-axis labeled "comments":
foreign_comments_df['Language'].value_counts().head(25).plot(kind='bar', title='Confusing Top Non-English Comments Identified by Lingua Py', ylabel='comments')

# %%
foreign_comments_df.head()

# %%
# table of top 10 languages, excluding unknown:
comments_df[comments_df['Language'] != 'unknown']['Language'].value_counts().head(100).to_frame()

# %%
# tried and nix'd, we're throwing out non-english comments
#translate_comments_with_progress(foreign_comments_df)

# %%
#en comments:
en_comments_df = comments_df[comments_df['Language'] == 'EN']

# %%
en_comments_df.head()

# %%
# saving en_comment_df:
en_comments_df.to_csv('/content/drive/MyDrive/Dat490/Data/en_comments.csv', index=False)

# %%
# tried and nix'd, we're throwing out non-english comments
import openai
import os
import time
import pandas as pd
from tqdm import tqdm

openai.api_key = ### It's a secret ###

# Token limit settings
TOKENS_PER_MINUTE_LIMIT = 80000
TOKEN_USAGE = 0
LAST_RESET_TIME = time.time()

# File paths for checkpointing
INDEX_FILE = 'index.txt'
CHECKPOINT_FILE = 'partial_translations.csv'

# Function to track token usage
def track_token_usage(token_count):
    global TOKEN_USAGE, LAST_RESET_TIME
    current_time = time.time()

    if current_time - LAST_RESET_TIME > 60:
        TOKEN_USAGE = 0
        LAST_RESET_TIME = current_time

    if TOKEN_USAGE + token_count > TOKENS_PER_MINUTE_LIMIT:
        wait_time = 60 - (current_time - LAST_RESET_TIME)
        print(f"Token limit reached, waiting {wait_time:.2f} seconds...")
        time.sleep(wait_time)
        TOKEN_USAGE = 0
        LAST_RESET_TIME = time.time()

    TOKEN_USAGE += token_count

# Function to translate a comment using GPT-3.5-turbo
def translate_comment(text):
    prompt = f"Translate the following text to English: '{text}' (text may already be in English). Respond back in only this format: 'OG_lang | translation'."
    promp2 = f'I am going to give you inputs in JSON and you will output JSON. We are translating comments. Use the two letter ISO code to identify the original language. Reply in the format {"lang": "", "translation": ""}'

    while True:
        try:
            prompt_tokens = len(prompt.split())
            track_token_usage(prompt_tokens)

            # Make the OpenAI API request
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You are a helpful assistant that translates text."},
                    {"role": "user", "content": prompt}
                ]
            )

            # Track tokens used by the response
            response_tokens = response['usage']['total_tokens']
            track_token_usage(response_tokens)

            return response['choices'][0]['message']['content'].strip()

        except openai.error.RateLimitError:
            time.sleep(10)  # Wait before retrying on rate limit error
        except Exception as e:
            return None

# Function to read the last processed index from index.txt
def get_last_processed_index():
    if os.path.exists(INDEX_FILE):
        with open(INDEX_FILE, 'r') as f:
            return int(f.read().strip())
    return 0

# Function to save the current index to index.txt
def save_current_index(idx):
    with open(INDEX_FILE, 'w') as f:
        f.write(str(idx))

# Function to process translations with checkpointing
def translate_comments_with_progress(df):
    # Load the last processed index
    start_idx = get_last_processed_index()
    print(f"Resuming from index {start_idx}")

    # If checkpoint exists, update DataFrame with saved progress
    if os.path.exists(CHECKPOINT_FILE):
        df_checkpoint = pd.read_csv(CHECKPOINT_FILE)
        df.update(df_checkpoint)

    # Iterate through comments from the last saved index
    for idx, row in tqdm(df.iloc[start_idx:].iterrows(), total=len(df) - start_idx, desc="Translating comments"):
        if pd.notnull(row['translated_comment']) and row['translated_comment'].strip() != "":
            continue  # Skip if already translated

        # Translate the comment
        translated_text = translate_comment(row['review'])
        if translated_text is not None:
            df.loc[idx + start_idx, 'translated_comment'] = translated_text
        else:
            print(f"Translation failed for row {idx + start_idx}")

        # Save progress every 1000 comments
        if (idx + start_idx + 1) % 1000 == 0:
            df.to_csv(CHECKPOINT_FILE, index=False)
            save_current_index(idx + start_idx + 1)
            print(f"Progress saved at index {idx + start_idx + 1}")

    # Save final result
    df.to_csv('translated_foreign_comments.csv', index=False)

# %%
# loading in en_comments:
en_comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/en_comments.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#tag_df.to_csv('/content/drive/MyDrive/Dat490/Data/tag_count.csv', index=False)
# loading in tag_df:
tag_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/tag_count.csv')

#loading in genre_df:
genre_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/genre_count.csv')

#genre_df.to_csv('/content/drive/MyDrive/Dat490/Data/genre_count.csv', index = False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
tag_set = set(tag_df['tag'].unique())
genre_set = set(genre_df['genre'].unique())
game_features = tag_set.union(genre_set)

def count_game_feature_mentions(tokens, game_features):
    mentions = {feature: 0 for feature in game_features}
    for token in tokens:
        if token in game_features:
            mentions[token] += 1
    return mentions
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
en_comments_df.sample(10)

# %%
# Install necessary libraries
print("Installing libraries...")
# !pip install --upgrade gensim nltk pyLDAvis
# !pip install spacy
# !pip install wordcloud
# !python -m spacy download en_core_web_sm

# Import libraries
import pandas as pd
import gensim
from gensim.utils import simple_preprocess
from gensim.models.phrases import Phrases, Phraser
import nltk
from nltk.corpus import stopwords
from gensim.corpora import Dictionary
from gensim.models import LdaMulticore
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Setup
print("Setting up...")
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define important short words to retain
important_short_words = {'ai', 'xp', 'gg', 'hp', 'mp', 'rp', 'bt', 'cd', 'dc', 'ks'}

# Ensure DataFrame is loaded
try:
    en_comments_df
except NameError:
    raise NameError("DataFrame 'en_comments_df' is not loaded. Please load your DataFrame before running the script.")

# Preprocessing function
def preprocess_text(text, min_length=3, exceptions=None):
    if exceptions is None:
        exceptions = set()
    tokens = simple_preprocess(str(text), deacc=True)
    tokens = [token for token in tokens if token not in stop_words and (len(token) >= min_length or token in exceptions)]
    return tokens

# Apply preprocessing with a single progress bar
print("Tokenizing and cleaning reviews...")
en_comments_df['tokens'] = [preprocess_text(review, min_length=3, exceptions=important_short_words) for review in tqdm(en_comments_df['review'], desc="Processing", leave=False)]

# Create bigram and trigram models
print("Creating bigram and trigram models...")
bigram = Phrases(en_comments_df['tokens'], min_count=5, threshold=100)
trigram = Phrases(bigram[en_comments_df['tokens']], threshold=100)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)

# Apply bigrams and trigrams with a single progress bar
from tqdm import tqdm
tqdm.pandas()

print("Applying bigrams and trigrams...")
en_comments_df['bigrams'] = [bigram_mod[tokens] for tokens in tqdm(en_comments_df['tokens'], desc="Bigrams", leave=False)]
en_comments_df['trigrams'] = [trigram_mod[tokens] for tokens in tqdm(en_comments_df['bigrams'], desc="Trigrams", leave=False)]

# Combine unigrams, bigrams, and trigrams
print("Combining unigrams and bigrams/trigrams...")
en_comments_df['final_tokens'] = en_comments_df['trigrams']

# Display a sample to verify (suppressing the automatic display of large DataFrame outputs)
print("Sample of preprocessed data:")
sample_output = en_comments_df[['review', 'final_tokens']].head()
print(sample_output.to_string(index=False))

# %%
# save the processed df:
#en_comments_df.to_csv('/content/drive/MyDrive/Dat490/Data/en_comments_processed.csv', index=False)

# load processed comments:
en_comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/en_comments_processed.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Check for missing values in 'tokens' and 'final_tokens'
print("Missing values in 'tokens':", en_comments_df['tokens'].isnull().sum())
print("Missing values in 'final_tokens':", en_comments_df['final_tokens'].isnull().sum())

# Check for empty lists
empty_tokens = en_comments_df['tokens'].apply(len) == 0
empty_final_tokens = en_comments_df['final_tokens'].apply(len) == 0
print("Empty 'tokens' lists:", empty_tokens.sum())
print("Empty 'final_tokens' lists:", empty_final_tokens.sum())
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Missing values in 'tokens': 0
# Missing values in 'final_tokens': 0
# Empty 'tokens' lists: 0
# Empty 'final_tokens' lists: 0

# %%
# Check for missing values in 'final_tokens'
missing_tokens = en_comments_df['final_tokens'].isnull().sum()
print(f"Missing 'final_tokens': {missing_tokens}")

# Check for empty token lists
empty_tokens = en_comments_df['final_tokens'].apply(len) == 0
print(f"Empty 'final_tokens' lists: {empty_tokens.sum()}")
# Out:
# Missing 'final_tokens': 0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empty 'final_tokens' lists: 0

# %%
# Number of tokens per document
en_comments_df['token_count'] = en_comments_df['final_tokens'].apply(len)

# Basic statistics
print("Basic Statistics of Token Counts:")
print(en_comments_df['token_count'].describe())

# Plot distribution
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(en_comments_df['token_count'], bins=50, kde=True)
plt.title('Distribution of Token Counts per Document')
plt.xlabel('Number of Tokens')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Basic Statistics of Token Counts:
# count    648481.000000
# mean        472.757905
# std         751.884708
# min           2.000000
# 25%         103.000000
# 50%         229.000000
# 75%         505.000000
# max       10639.000000
# Name: token_count, dtype: float64

# %%
# Inspect the first few entries of final_tokens to understand its structure
print(en_comments_df['final_tokens'].head(5))

# Check the type and structure of entries in 'final_tokens'
print("Inspecting the first 5 entries in 'final_tokens':")
for i, entry in enumerate(en_comments_df['final_tokens'].head(5)):
    print(f"Entry {i}: Type - {type(entry)}, Content - {entry}")
# Out:
# 0    ['review', 'autoclick', 'works', 'wish', 'like...
# 1    ['refuses', 'start', 'without', 'downloading',...
# 2    ['awesome', 'auto_clicker', 'way', 'assemble',...
# 3    ['really', 'like', 'thanks', 'making', 'availa...
# 4    ['beginning', 'thought', 'program', 'would', '...
# Name: final_tokens, dtype: object
# Inspecting the first 5 entries in 'final_tokens':
# Entry 0: Type - <class 'str'>, Content - ['review', 'autoclick', 'works', 'wish', 'like', 'dual', 'mouse_cursor', 'option', 'afking', 'click', 'another', 'screen', 'multitask', 'mouse_cursor', 'update', 'review', 'sometime', 'buying', 'support', 'dev', 'updated', 'review', 'move', 'cursor', 'multitask', 'using', 'dual', 'monitor', 'works', 'without', 'interrupting', 'tasks']
# Entry 1: Type - <class 'str'>, Content - ['refuses', 'start', 'without', 'downloading', 'third', 'party', 'software', 'also', 'refuses', 'send', 'working', 'link', 'download', 'third', 'party', 'program']
# Entry 2: Type - <class 'str'>, Content - ['awesome', 'auto_clicker', 'way', 'assemble', 'loops', 'little', 'blocks', 'absolutely', 'perfect', 'trivial', 'set', 'loop', 'minutes', 'absolutely', 'perfect', 'start', 'stop', 'clicking', 'button', 'restarting', 'loop', 'tinkering', 'convenient', 'fine', 'tune', 'precisely', 'without', 'ever', 'edit', 'text', 'file', 'quick', 'set', 'could', 'configure', 'dozen', 'games', 'screen', 'every', 'morning', 'never', 'even', 'need', 'worry', 'saving', 'positioning', 'windows', 'hands', 'best', 'autoclicker', 'steam', 'fairly', 'new', 'expect', 'get', 'even', 'better', 'time', 'course', 'autohotkey', 'pain', 'modify', 'old', 'script', 'add', 'game', 'big', 'sequence', 'programmed', 'whereas', 'app', 'drag', 'around', 'boxes', 'adjust', 'instantly', 'ahk', 'nice', 'way', 'powerful', 'half', 'time', 'script', 'logic', 'trying', 'control', 'starting', 'stopping', 'escaping', 'since', 'write', 'crazy', 'script', 'run', 'rampant', 'start', 'stop', 'button', 'functioning', 'default', 'ease', 'dragging', 'boxes', 'around', 'create', 'loop', 'amazing', 'ever', 'really', 'wanted']
# Entry 3: Type - <class 'str'>, Content - ['really', 'like', 'thanks', 'making', 'available', 'functions', 'free', 'autoclicker', 'additional', 'things', 'recordings', 'macros', 'fixed', 'positions', 'allows', 'click', 'several', 'places', 'row', 'clicker', 'idle', 'veteran', 'wonderful', 'thing', 'definitely', 'worth', 'price', 'thumbs', 'edit', 'looks', 'beautiful']
# Entry 4: Type - <class 'str'>, Content - ['beginning', 'thought', 'program', 'would', 'fulfill', 'necessary', 'expectations', 'thought', 'would', 'deal', 'everything', 'sake', 'achievements', 'last', 'moment', 'looked', 'something', 'understood', 'program', 'needs', 'used', 'functionality', 'useless', 'saying', 'goodbye', 'unofficial', 'app', 'using', 'purchasing', 'app']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import ast
from collections import Counter

# Step 1: Convert each entry in 'final_tokens' from a string to a list using `ast.literal_eval`
en_comments_df['final_tokens'] = en_comments_df['final_tokens'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Step 2: Flatten the list of tokens from 'final_tokens'
all_tokens = [token for tokens_list in en_comments_df['final_tokens'] for token in tokens_list]

# Step 3: Count the frequency of each token
token_freq = Counter(all_tokens)

# Step 4: Get the 200 most common tokens/phrases
common_tokens = token_freq.most_common(500)

# Step 5: Print the top 200 most common tokens/phrases
print("\nTop 200 Most Common Tokens/Phrases:")
for token, freq in common_tokens:
    print(f"{token}: {freq}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top 200 Most Common Tokens/Phrases:
# game: 1257349
# like: 350560
# fun: 222379
# good: 211868
# really: 207368
# get: 196208
# one: 192762
# play: 185173
# time: 175717
# games: 169765
# great: 147198
# would: 146578
# even: 142443
# also: 135225
# much: 124606
# story: 124252
# well: 108919
# lot: 106530
# first: 105471
# make: 100991
# still: 100985
# love: 100293
# way: 98015
# gameplay: 94223
# see: 93195
# feel: 89225
# new: 88151
# playing: 87009
# recommend: 85166
# played: 81356
# could: 80546
# little: 80101
# hours: 78540
# think: 78350
# want: 76680
# bit: 76614
# better: 75364
# things: 73358
# pretty: 73229
# feels: 69079
# every: 67172
# many: 66952
# experience: 65612
# worth: 64532
# need: 63905
# different: 63363
# characters: 63239
# far: 60759
# level: 59898
# back: 59595
# something: 59371
# people: 57674
# made: 56149
# got: 55958
# find: 55200
# around: 55140
# nice: 54939
# best: 54641
# bad: 54472
# character: 54281
# work: 54210
# combat: 54119
# enough: 53213
# overall: 52389
# say: 52342
# though: 52327
# world: 50946
# know: 50657
# right: 50420
# going: 50379
# hard: 50051
# use: 48260
# give: 47818
# graphics: 47359
# mechanics: 47092
# makes: 47015
# easy: 46661
# content: 45829
# run: 45553
# everything: 45443
# enemies: 45360
# player: 45023
# bugs: 44871
# thing: 44666
# interesting: 44593
# system: 44401
# price: 44192
# take: 44071
# long: 43792
# review: 43603
# music: 43509
# end: 43359
# since: 43230
# quite: 43152
# definitely: 43088
# actually: 42970
# never: 42744
# buy: 42485
# keep: 42264
# point: 41996
# style: 41949
# times: 41939
# looking: 41824
# without: 40384
# players: 40173
# look: 40150
# mode: 40034
# start: 39509
# enjoy: 39379
# getting: 39281
# try: 39262
# short: 38949
# however: 38710
# amazing: 38592
# issues: 37644
# map: 37586
# art: 37431
# maybe: 37404
# steam: 36806
# full: 36437
# cool: 35963
# nothing: 35890
# levels: 35726
# making: 35418
# two: 35378
# another: 35344
# unique: 35335
# devs: 35292
# design: 35070
# early_access: 35052
# money: 34982
# especially: 34658
# ever: 34383
# sure: 34370
# hope: 33800
# puzzles: 33488
# already: 33379
# yet: 33259
# simple: 33135
# difficulty: 32827
# might: 32614
# wait: 32389
# able: 32289
# always: 31573
# put: 31512
# main: 31281
# part: 31016
# done: 30951
# build: 30809
# anything: 30724
# real: 30636
# needs: 30611
# items: 30426
# building: 30412
# super: 30278
# next: 30116
# seems: 30084
# big: 29957
# puzzle: 29596
# add: 29477
# come: 28885
# trying: 28791
# absolutely: 28667
# friends: 28649
# life: 28621
# stuff: 28508
# sometimes: 28285
# found: 28211
# original: 27970
# enjoyed: 27917
# probably: 27609
# day: 27174
# kind: 27108
# least: 27028
# weapons: 26745
# future: 26744
# release: 26729
# wish: 26718
# instead: 26503
# may: 26170
# almost: 26105
# less: 26069
# change: 25857
# enemy: 25839
# genre: 25670
# felt: 25581
# gets: 25423
# based: 25392
# small: 25090
# turn: 25029
# controls: 24859
# potential: 24848
# let: 24538
# last: 24464
# cute: 24302
# amount: 24249
# highly: 24135
# fan: 24109
# horror: 23775
# looks: 23639
# updates: 23583
# forward: 23579
# single: 23535
# ai: 23388
# either: 23279
# version: 23259
# perfect: 23055
# said: 23014
# enjoyable: 22973
# boss: 22937
# options: 22927
# dev: 22740
# update: 22559
# solid: 22515
# team: 22308
# used: 22223
# beautiful: 22068
# issue: 21983
# complete: 21896
# free: 21816
# whole: 21813
# old: 21604
# hit: 21479
# etc: 21441
# developers: 21297
# high: 21267
# help: 21158
# difficult: 21117
# series: 21104
# challenging: 20751
# variety: 20569
# reviews: 20543
# runs: 20536
# developer: 20521
# progress: 20498
# second: 20399
# thought: 20392
# using: 20158
# idea: 20124
# set: 20015
# side: 20004
# screen: 19972
# honestly: 19963
# rather: 19927
# lots: 19888
# certain: 19812
# place: 19782
# minutes: 19597
# decent: 19512
# yes: 19269
# save: 19259
# loved: 19198
# move: 19152
# unlock: 19123
# understand: 19090
# takes: 19058
# awesome: 19054
# away: 18962
# works: 18935
# added: 18708
# later: 18638
# fantastic: 18624
# features: 18611
# quality: 18546
# seem: 18425
# early: 18343
# support: 18294
# completely: 18289
# damage: 18287
# please: 18277
# extremely: 18277
# reason: 18269
# type: 18259
# left: 18157
# years: 18118
# challenge: 18100
# fight: 18092
# upgrades: 18064
# open: 18063
# must: 18037
# often: 17875
# sound: 17874
# top: 17868
# seen: 17841
# pick: 17782
# similar: 17717
# spoiler: 17608
# boring: 17589
# else: 17559
# sense: 17546
# cannot: 17505
# option: 17394
# fix: 17358
# someone: 17347
# beat: 17302
# wanted: 17282
# atmosphere: 17257
# sale: 17146
# others: 17109
# fine: 17073
# multiple: 17069
# tell: 16997
# problem: 16780
# movement: 16764
# due: 16717
# lack: 16619
# hour: 16606
# base: 16600
# learn: 16591
# annoying: 16532
# points: 16499
# despite: 16429
# expect: 16406
# deck: 16404
# progression: 16376
# took: 16338
# couple: 16337
# satisfying: 16267
# slow: 16255
# elements: 16241
# feeling: 16207
# achievements: 16196
# huge: 15990
# upgrade: 15913
# fact: 15879
# half: 15861
# fast: 15825
# depth: 15810
# liked: 15796
# basically: 15757
# ending: 15734
# everyone: 15723
# weapon: 15697
# multiplayer: 15689
# together: 15642
# year: 15637
# kinda: 15605
# fixed: 15595
# finished: 15565
# bosses: 15559
# although: 15508
# maps: 15473
# demo: 15456
# dont: 15432
# random: 15428
# bought: 15382
# writing: 15339
# concept: 15313
# mostly: 15184
# easily: 15010
# entire: 15007
# running: 14999
# comes: 14995
# action: 14994
# settings: 14969
# fps: 14782
# soundtrack: 14763
# room: 14758
# job: 14739
# cant: 14697
# mechanic: 14662
# setting: 14646
# anyone: 14631
# frustrating: 14604
# quickly: 14593
# low: 14569
# mind: 14567
# visuals: 14537
# attack: 14451
# skills: 14374
# missions: 14359
# stuck: 14285
# engaging: 14218
# ways: 14169
# final: 14155
# simply: 14144
# ability: 14139
# area: 14107
# goes: 14067
# grind: 14061
# days: 13947
# cards: 13918
# kill: 13917
# list: 13909
# areas: 13904
# example: 13839
# die: 13831
# finish: 13800
# ones: 13724
# become: 13691
# gives: 13672
# truly: 13671
# basic: 13628
# survival: 13627
# online: 13614
# space: 13570
# dialogue: 13556
# recommended: 13536
# community: 13450
# click: 13449
# excellent: 13438
# finally: 13431
# longer: 13402
# working: 13380
# person: 13352
# possible: 13338
# explore: 13334
# coming: 13307
# development: 13306
# dlc: 13267
# spend: 13206
# negative: 13204
# parts: 13198
# stop: 13195
# moment: 13168
# limited: 13153
# favorite: 13148
# choose: 13145
# read: 13122
# strategy: 13120
# given: 13112
# choices: 13070
# control: 13056
# tutorial: 13054
# weird: 13052
# abilities: 12990
# literally: 12938
# speed: 12901
# previous: 12897
# adventure: 12891
# incredibly: 12842
# several: 12834
# relaxing: 12767
# tried: 12766
# button: 12762
# means: 12700
# title: 12697
# loop: 12690
# actual: 12653
# wrong: 12633
# lost: 12619
# resources: 12619
# bug: 12612
# mission: 12612
# currently: 12594
# clear: 12548
# past: 12533
# three: 12517
# edit: 12503
# menu: 12499
# fighting: 12450
# exploration: 12434
# skill: 12373
# needed: 12335
# released: 12235
# funny: 12226
# available: 12199
# battle: 12155
# changes: 12151
# campaign: 12139
# started: 12119
# spent: 12074
# performance: 12012
# missing: 12003
# quick: 11966
# repetitive: 11952
# excited: 11934
# giving: 11899
# classic: 11860
# special: 11795
# buying: 11784
# check: 11755
# animations: 11724
# quests: 11707
# happy: 11692
# figure: 11644
# controller: 11633
# close: 11621
# personally: 11616
# went: 11610
# came: 11568
# waiting: 11531
# opinion: 11509
# along: 11473
# care: 11403
# fans: 11377
# item: 11375
# unless: 11294
# rpg: 11256
# number: 11168
# indie: 11162
# core: 11139
# seeing: 11134
# balance: 11130
# continue: 11114
# extra: 11071
# create: 11066
# gaming: 11000
# unfortunately: 10976
# problems: 10967

# %%
# Extract bigrams and trigrams (tokens with '_')
bigram_trigram_tokens = [token for token in all_tokens if '_' in token]

# Count frequency
bigram_trigram_freq = Counter(bigram_trigram_tokens)

# Top 50
common_bigrams_trigrams = bigram_trigram_freq.most_common(500)
print("\nTop 50 Most Common Bigrams/Trigrams:")
for token, freq in common_bigrams_trigrams:
    print(f"{token}: {freq}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Top 50 Most Common Bigrams/Trigrams:
# early_access: 35052
# voice_acting: 9696
# current_state: 6816
# pixel_art: 5069
# old_school: 3986
# boss_fights: 3854
# tower_defense: 3765
# fast_paced: 3698
# visual_novel: 3654
# replay_value: 3423
# price_tag: 3411
# sound_effects: 3410
# years_ago: 3346
# vampire_survivors: 3344
# jump_scares: 3128
# https_steamcommunity: 2820
# city_builder: 2763
# store_steampowered_com_curator: 2722
# bullet_hell: 2664
# com_sharedfiles_filedetails: 2660
# learning_curve: 2547
# https_youtu: 2521
# skill_tree: 2147
# meta_progression: 2130
# attention_detail: 2039
# url_https_store_steampowered: 1982
# top_notch: 1796
# slay_spire: 1785
# cut_scenes: 1783
# stardew_valley: 1775
# resource_management: 1772
# dark_souls: 1762
# fast_travel: 1731
# hidden_gem: 1696
# https_www_youtube_com: 1687
# power_ups: 1666
# rogue_lite: 1510
# replay_ability: 1480
# bare_bones: 1447
# hidden_object: 1427
# hollow_knight: 1424
# url_url_https: 1360
# pay_attention: 1342
# cash_grab: 1322
# store_page: 1304
# walking_simulator: 1292
# trial_error: 1286
# forget_reality: 1283
# heard_minor: 1269
# difficult_dark_souls: 1258
# audience_kids_teens_adults: 1250
# run_paint_potato: 1245
# ask_nasa_spare_computer: 1225
# mouse_keyboard: 1222
# game_big_terrarium: 1222
# lore_average: 1202
# pleasantly_surprised: 1202
# enough_cup_coffee: 1201
# fast_rich_boi: 1199
# average_long_infinity: 1194
# annoying_ark_survival_evolved: 1188
# bad_bad_deaf: 1187
# lovely_replace: 1185
# mehh_watch_paint_dry: 1183
# keyboard_mouse: 1183
# unreal_engine: 1176
# price_sale_spare: 1173
# anyone_likes: 1170
# higher_difficulties: 1168
# look_long_dos: 1163
# master_significant_brain_usage: 1156
# grind_care_leaderboards: 1153
# visual_novels: 1147
# high_hopes: 1146
# frame_rate: 1137
# instead_audio_eargasm: 1118
# ranks_necessary_progress: 1118
# bug_fixes: 1108
# hack_slash: 1108
# risk_rain: 1105
# locked_behind: 1103
# auto_battler: 1089
# tech_tree: 1080
# grandma_requirements_check: 1079
# easter_eggs: 1070
# chilla_art: 1055
# bullet_heaven: 1046
# url_quote: 1042
# save_file: 1032
# star_trek: 1031
# dungeon_crawler: 1027
# mega_man: 1027
# copy_paste: 1022
# scratches_itch: 1007
# dead_cells: 1007
# breath_fresh_air: 1005
# beans_take_beans_take: 995
# english_translation: 984
# https_store_steampowered_com: 975
# total_war: 967
# voice_actors: 966
# resident_evil: 959
# party_members: 951
# com_curator: 939
# farming_sim: 927
# lethal_company: 918
# micro_transactions: 917
# loading_screens: 916
# deck_builder: 914
# anyone_enjoys: 909
# boomer_shooter: 892
# kingdom_hearts: 888
# overstay_welcome: 871
# cup_tea: 867
# half_baked: 865
# ghost_hunting: 841
# skill_trees: 834
# rough_edges: 827
# city_builders: 821
# voice_lines: 816
# randomly_generated: 815
# animal_crossing: 810
# wide_variety: 809
# double_jump: 788
# control_scheme: 781
# follow_url_https: 780
# asset_flip: 774
# silent_hill: 766
# nowhere_near: 762
# non_existent: 761
# scratch_itch: 761
# url_https_steamcommunity_com: 752
# steamcommunity_com: 743
# size_floppy: 742
# disk_old_fashioned_workable: 740
# drive_hold: 740
# tower_defence: 740
# invest_black_hole_hold: 738
# quote_url_https: 737
# frame_drops: 721
# darkest_dungeon: 721
# hand_drawn: 720
# vampire_survivor: 715
# house_flipper: 714
# post_apocalyptic: 708
# user_interface: 703
# deal_breaker: 698
# blown_away: 692
# psychological_horror: 692
# caw_caw: 688
# live_service: 686
# revolves_around: 685
# star_wars: 683
# ai_generated: 680
# ace_attorney: 674
# slow_paced: 669
# visually_stunning: 665
# rinse_repeat: 660
# paying_attention: 657
# qol_improvements: 654
# black_white: 652
# rpg_maker: 650
# curator_page: 649
# cut_scene: 645
# spiritual_successor: 645
# url_https: 644
# com_app: 641
# thought_provoking: 639
# nancy_drew: 639
# low_poly: 635
# anyone_loves: 634
# metal_gear: 634
# user_friendly: 633
# monster_hunter: 633
# dungeon_keeper: 627
# ratchet_clank: 625
# months_ago: 624
# baldur_gate: 619
# passion_project: 616
# dragon_quest: 616
# voice_chat: 609
# elden_ring: 608
# bite_sized: 604
# hand_holding: 599
# motion_sickness: 598
# health_bar: 596
# discord_server: 588
# armored_core: 586
# steep_learning_curve: 582
# xbox_controller: 552
# like_slay_spire: 552
# dungeon_crawling: 549
# resource_gathering: 548
# twists_turns: 547
# rogue_likes: 545
# ghost_trick: 545
# fetch_quests: 542
# gameplay_https_youtu: 541
# biggest_gripe: 540
# street_fighter: 539
# youtube_com_watch: 538
# harder_difficulties: 538
# mixed_bag: 538
# risk_reward: 536
# action_packed: 529
# poorly_optimized: 520
# vast_majority: 520
# impressions_https_youtu: 519
# saints_row: 519
# jump_scare: 518
# permanent_upgrades: 517
# table_table: 499
# dating_sim: 499
# keeping_eye: 498
# visually_appealing: 494
# step_step: 494
# bare_minimum: 489
# farming_sims: 488
# harvest_moon: 488
# football_manager: 488
# requested_refund: 487
# beautifully_crafted: 486
# missed_opportunity: 485
# south_park: 484
# rusty_lake: 484
# holy_shit: 479
# edge_seat: 476
# attack_patterns: 475
# invisible_walls: 471
# exceeded_expectations: 468
# light_hearted: 463
# free_roam: 463
# comic_book: 462
# curator_page_url: 456
# difficulty_spike: 453
# wide_range: 450
# keeps_crashing: 450
# procedurally_generated: 449
# mixed_feelings: 445
# medieval_dynasty: 444
# dwarf_fortress: 443
# season_pass: 439
# side_scrolling: 439
# extraction_shooter: 437
# league_legends: 437
# fine_tuning: 433
# without_spoiling: 433
# worth_price_admission: 431
# youtube_channel: 430
# camera_angle: 428
# motion_blur: 428
# social_media: 427
# rabi_ribi: 425
# sets_apart: 424
# plot_twists: 424
# anti_cheat: 423
# night_cycle: 423
# source_material: 423
# tony_hawk: 423
# falls_flat: 421
# grand_strategy: 419
# twin_stick_shooter: 418
# hide_seek: 416
# camera_angles: 416
# target_audience: 414
# review_https_youtu: 414
# cities_skylines: 410
# boomer_shooters: 407
# follow_curator: 406
# kingdom_rush: 404
# colony_sim: 403
# jet_set_radio: 403
# windowed_mode: 402
# pun_intended: 402
# copy_pasted: 401
# voice_acted: 401
# quote_quote: 398
# looter_shooter: 397
# dead_daylight: 397
# train_valley: 394
# min_max: 391
# deck_builders: 390
# steering_wheel: 389
# battle_royale: 387
# modding_community: 387
# youtube_videos: 387
# soft_locked: 386
# expanded_upon: 385
# vice_versa: 384
# narrative_driven: 382
# remaster_evolution_remaster_evolution: 382
# line_sight: 381
# rage_quit: 381
# color_palette: 380
# brute_force: 380
# keeps_toes: 378
# grain_salt: 378
# talos_principle: 378
# call_duty: 375
# moneys_worth: 375
# roguelike_deckbuilder: 373
# overly_complicated: 372
# observation_duty: 372
# personal_preference: 370
# ender_lilies: 370
# mind_blowing: 369
# hotline_miami: 368
# final_verdict: 367
# gaming_industry: 362
# voice_actor: 361
# fire_emblem: 360
# voice_overs: 359
# anywhere_near: 357
# rocket_league: 357
# sense_accomplishment: 356
# space_marine: 355
# ubisoft_connect: 355
# party_member: 352
# cultist_simulator: 352
# slice_life: 351
# status_effects: 348
# dodge_roll: 348
# doom_eternal: 347
# curator_url: 347
# gas_station: 345
# smash_bros: 345
# talent_tree: 344
# cloud_saves: 343
# cherry_top: 340
# slow_motion: 339
# pleasant_surprise: 338
# pain_ass: 337
# crew_members: 337
# lowest_settings: 336
# garten_banban: 336
# fully_voiced: 334
# bug_reports: 333
# cooking_companions: 333
# nintendo_switch: 332
# deep_rock_galactic: 332
# internet_connection: 332
# gonna_lie: 331
# arrow_keys: 330
# double_dragon: 330
# tomb_raider: 329
# url_store_steampowered: 329
# side_scroller: 328
# auto_aim: 325
# nothing_offer_shrine: 325
# deluxe_edition: 324
# stumbled_upon: 323
# smile_face: 323
# production_chains: 321
# pop_culture: 320
# heart_soul: 318
# curator_page_url_https: 318
# dirt_rally: 318
# aesthetically_pleasing: 317
# mental_health: 317
# real_estate: 316
# mouse_sensitivity: 312
# pre_alpha: 312
# martial_arts: 312
# expand_factory: 311
# beginner_friendly: 310
# keeps_engaged: 309
# project_zomboid: 309
# grappling_hook: 309
# worthy_successor: 307
# sex_scenes: 306
# www_youtube: 305
# scratched_itch: 305
# absolute_banger: 305
# proof_concept: 304
# dungeon_crawlers: 303
# binding_isaac: 302
# soft_lock: 298
# kept_engaged: 298
# heavily_inspired: 291
# murder_mystery: 291
# fingers_crossed: 290
# input_lag: 290
# min_maxing: 290
# mentioned_earlier: 290
# rad_codex: 290
# visually_pleasing: 289
# theme_park: 289
# bang_buck: 287
# jokes_aside: 286
# branching_paths: 286
# lack_luster: 285
# nine_sols: 285
# git_gud: 283
# easter_egg: 283
# fairy_tail: 283
# family_friendly: 281
# bullet_sponges: 280
# request_refund: 280
# heart_lungs_liver_nerves: 280
# blade_sorcery: 277
# skibidi_toilet: 277
# hidden_gems: 275
# dave_diver: 275
# achievement_hunting: 274
# cosmic_horror: 273
# button_mashing: 273
# forza_horizon: 272
# latest_patch: 272
# fever_dream: 272
# scratched_surface: 270
# spoilers_ahead: 270
# procedural_generation: 269
# twin_stick: 269
# metal_slug: 269
# damage_output: 266
# high_skill_ceiling: 266
# rune_factory: 266
# jagged_alliance: 266
# regency_solitaire: 266
# subject_matter: 265
# star_ocean: 265
# recent_memory: 264
# memory_leak: 264
# mileage_may_vary: 264
# sea_thieves: 264
# men_war: 264
# https_www: 263
# poorly_executed: 262
# burger_shop: 262
# alt_tab: 261
# ambient_sounds: 261
# strengths_weaknesses: 261
# oxygen_included: 260
# anime_girls: 260
# anytime_soon: 259
# eye_candy: 259
# frame_rates: 257
# review_bombing: 256
# poorly_implemented: 256
# walkthrough_https_youtu: 254
# fall_flat: 253
# short_bursts: 253
# halls_torment: 252
# breaks_immersion: 252
# pocket_mirror: 252
# early_acces: 251
# supermarket_simulator: 251
# chef_kiss: 251
# undo_button: 251
# iron_lung: 251
# legend_bowl: 251
# papers_please: 250
# premium_currency: 249
# fatal_error: 249
# forgot_mention: 249
# scattered_throughout: 249
# star_fox: 249
# slot_machine: 248
# micro_management: 248
# mobile_app: 248
# buffs_debuffs: 246
# previously_mentioned: 246
# meticulously_crafted: 246
# goat_simulator: 246
# https_steamcommunity_com_groups: 246
# ion_fury: 246
# melee_ranged: 245
# old_fashioned: 243
# caught_attention: 242
# precision_platformer: 242
# mind_numbing: 241
# painfully_slow: 241
# rock_paper_scissors: 241
# buttery_smooth: 241
# research_tree: 241
# diamond_rough: 240
# mouse_cursor: 239
# video_https_youtu: 239
# fetch_quest: 239
# coral_island: 239
# answer_questions: 239
# falls_apart: 238
# cross_platform: 237
# skill_ceiling: 237
# sink_teeth: 236
# auto_battlers: 236
# poorly_explained: 236
# last_epoch: 236
# battle_brothers: 236
# assassin_creed: 236
# dragon_dogma: 236
# sonar_shock: 236
# arcade_racer: 235
# environmental_storytelling: 235
# every_nook_cranny: 235
# overwhelmingly_positive: 235
# caught_guard: 235
# civil_war: 235
# task_manager: 234
# www_youtube_com: 234

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from wordcloud import WordCloud

# Word cloud for unigrams
wordcloud_unigram = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(token_freq)

plt.figure(figsize=(15, 7.5))
plt.imshow(wordcloud_unigram, interpolation='bilinear')
plt.axis('off')
plt.title('Top Unigrams Word Cloud')
plt.show()

# Word cloud for bigrams/trigrams
wordcloud_bigram_trigram = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(bigram_trigram_freq)

plt.figure(figsize=(15, 7.5))
plt.imshow(wordcloud_bigram_trigram, interpolation='bilinear')
plt.axis('off')
plt.title('Top Bigrams/Trigrams Word Cloud')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
from gensim.corpora import Dictionary
from gensim.models import LdaMulticore
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Step 1: Create a Dictionary from the 'final_tokens'
dictionary = Dictionary(en_comments_df['final_tokens'])

# Step 2: Filter extremes to remove very common and very rare tokens
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# Step 3: Create a Bag-of-Words Corpus
corpus = [dictionary.doc2bow(tokens) for tokens in en_comments_df['final_tokens']]
# Out:
# Streaming output truncated to the last 5000 lines.
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-736:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-737:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-738:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-739:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-740:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-741:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-742:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-743:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-744:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-745:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-746:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-747:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-748:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-749:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-750:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-751:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-752:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-753:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-754:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-755:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-756:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-757:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-758:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-759:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-760:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-761:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-762:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-763:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-764:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-765:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-766:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-767:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-768:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-769:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-770:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-771:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-772:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-773:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-774:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-775:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-776:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-777:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-778:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-779:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-780:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-781:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-782:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-783:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-784:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-785:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-786:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-787:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-788:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-789:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-790:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-791:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-792:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-793:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-794:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-795:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-796:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-797:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-798:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-799:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-800:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-801:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-802:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-803:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-804:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
# ...
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1097:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1098:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1099:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1100:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1101:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1102:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1103:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1104:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1105:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1106:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1107:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1108:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1109:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1110:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1111:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1112:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1113:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1114:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1115:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1116:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1117:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1118:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 104, in get
#     self._sem.release()
# ValueError: semaphore or lock released too many times
# Process ForkPoolWorker-1119:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 109, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.10/dist-packages/gensim/models/ldamulticore.py", line 341, in worker_e_step
#     chunk_no, chunk, w_state = input_queue.get()

# %% [markdown]
# # Do only one of these two:

# %%
import gc
gc.collect()
del corpus_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f9b65aa0cd63> in <cell line: 3>()
#       1 import gc
#       2 gc.collect()
# ----> 3 del corpus_df
#
# NameError: name 'corpus_df' is not defined

# %%
# Shortest viable test run to confirm the LDA setup works
num_topics_test = 5  # Minimal number of topics for a very quick test
lda_model_test = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics_test,  # Minimal number of topics
    random_state=100,
    chunksize=200,  # Small chunk size for memory efficiency
    passes=1,       # Single pass for speed
    iterations=10,  # Minimal iterations
    per_word_topics=True,
    workers=1       # Set to 1 for Colab free tier
)

# %%
# longer run, will take a long time ~10 to 30 mins

# Step 4: Build the LDA Model
num_topics = 25  # Adjust the number of topics as needed
lda_model = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,6
    random_state=100,
    chunksize=200,
    passes=10,
    iterations=100,
    per_word_topics=True,
    workers=2  # Use multiple cores for processing
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Step 5: Print the Topicscha
print("\nLDA Model Topics:")
for idx, topic in lda_model.print_topics(num_topics=num_topics, num_words=15):
    print(f"Topic {idx + 1}: {topic}")


# Step 6: Visualize the Topics (optional)
print("\nPreparing LDA Visualization...")
lda_visualization = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(lda_visualization)

# Save the visualization to an HTML file if needed
# pyLDAvis.save_html(lda_visualization, 'lda_visualization.html')

# %%
lda_topics_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/LDA renamed.csv')
en_comments_df = pd.read_csv('/content/drive/MyDrive/Dat490/Data/en_comments_processed.csv')

import re

# Step 1: Extract keywords for each topic
lda_topics = {}
for _, row in lda_topics_df.iterrows():
    topic_name = row['Renamed']  # Use the column name directly without renaming

    # Ensure the content is a string before processing
    if isinstance(row['content'], str):
        # Extract all words between double quotes using regex
        keywords = re.findall(r'"(.*?)"', row['content'])
        lda_topics[topic_name] = keywords

# Step 2: Create a function to assign LDA topics to comments
def assign_lda_topics(comment):
    comment = comment.lower()  # Convert to lowercase to ensure case-insensitive matching
    topics_found = []
    for topic, keywords in lda_topics.items():
        if any(keyword in comment for keyword in keywords):
            topics_found.append(topic)
    return topics_found

# %%
en_comments_df.sample()

# %%
# Step 3: Apply the function to `en_comments_processed` to create a new column for LDA topics
en_comments_df['lda_topics'] = en_comments_df['review'].apply(assign_lda_topics)

# Step 4: Summarize LDA topics per game (appid)
# Explode the 'lda_topics' list to create a row for each topic per comment
topics_exploded = en_comments_df.explode('lda_topics')

# Drop rows where 'lda_topics' is empty (no topic matched)
topics_exploded = topics_exploded.dropna(subset=['lda_topics'])

# Count the occurrences of each topic per game
topic_counts_per_game = topics_exploded.groupby(['appid', 'lda_topics']).size().reset_index(name='count')

# Get the top 10 topics per game
top_10_topics_per_game = topic_counts_per_game.groupby('appid').apply(
    lambda x: x.nlargest(10, 'count')
).reset_index(drop=True)

# Step 5: Aggregate the top topics into a list for each appid
top_topics_per_game = top_10_topics_per_game.groupby('appid')['lda_topics'].apply(list).reset_index()

# %%
top_topics_per_game
#saving as csv:
top_topics_per_game.to_csv('/content/drive/MyDrive/Dat490/Data/top_topics_per_game.csv', index=False)

# %%
# Check the structure of top_topics_per_game
print("Top Topics per Game:")
print(top_topics_per_game.head(10))

# Check the structure of features_df
print("\nFeatures DataFrame:")
print(features_df.head(10))

# Check the type of 'all_features' in both DataFrames
print("\nData type of 'all_features' in top_topics_per_game:")
print(type(top_topics_per_game['lda_topics'].iloc[0]))

print("\nData type of 'all_features' in features_df:")
print(type(features_df['all_features'].iloc[0]))
